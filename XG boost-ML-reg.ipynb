# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype='int')
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
param_grid={'n_estimators':[50,100,150,200],'booster':['gbtree','gblinear'],'min_child_weight':[1,2,3,4],'learning_rate':[0.01,0.1,1]}
grid=GridSearchCV(XGBRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bi...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'booster': ['gbtree', 'gblinear'],
#                          'learning_rate': [0.01, 0.1, 1],
#                          'min_child_weight': [1, 2, 3, 4],
#                          'n_estimators': [50, 100, 150, 200]},
#              verbose=3)

# %%
result=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.086738      0.012027         0.012560        0.002831
# 1        0.125207      0.009701         0.012771        0.002685
# 2        0.159173      0.006178         0.013473        0.004606
# 3        0.212462      0.007328         0.014987        0.003693
# 4        0.068406      0.012434         0.011932        0.003728
# ..            ...           ...              ...             ...
# 91       0.241150      0.064079         0.076111        0.058576
# 92       0.180059      0.059992         0.050856        0.016618
# 93       0.227135      0.100254         0.081167        0.053558
# 94       0.238139      0.078560         0.024148        0.009757
# 95       0.215638      0.064081         0.056698        0.027700
#
#    param_booster param_learning_rate param_min_child_weight  \
# 0         gbtree                0.01                      1
# 1         gbtree                0.01                      1
# 2         gbtree                0.01                      1
# 3         gbtree                0.01                      1
# 4         gbtree                0.01                      2
# ..           ...                 ...                    ...
# 91      gblinear                   1                      3
# 92      gblinear                   1                      4
# 93      gblinear                   1                      4
# 94      gblinear                   1                      4
# 95      gblinear                   1                      4
#
#    param_n_estimators                                             params  \
# 0                  50  {'booster': 'gbtree', 'learning_rate': 0.01, '...
# 1                 100  {'booster': 'gbtree', 'learning_rate': 0.01, '...
# 2                 150  {'booster': 'gbtree', 'learning_rate': 0.01, '...
# 3                 200  {'booster': 'gbtree', 'learning_rate': 0.01, '...
# 4                  50  {'booster': 'gbtree', 'learning_rate': 0.01, '...
# ..                ...                                                ...
# 91                200  {'booster': 'gblinear', 'learning_rate': 1, 'm...
# 92                 50  {'booster': 'gblinear', 'learning_rate': 1, 'm...
# 93                100  {'booster': 'gblinear', 'learning_rate': 1, 'm...
# 94                150  {'booster': 'gblinear', 'learning_rate': 1, 'm...
# 95                200  {'booster': 'gblinear', 'learning_rate': 1, 'm...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.546382           0.498460           0.524920
# 1            0.753784           0.694194           0.720370
# 2            0.829603           0.768660           0.794421
# 3            0.857106           0.797860           0.820202
# 4            0.551225           0.497535           0.525094
# ..                ...                ...                ...
# 91           0.763518           0.702949           0.730652
# 92           0.764638           0.706508           0.725475
# 93           0.764047           0.703807           0.730356
# 94           0.763575           0.703040           0.730626
# 95           0.763518           0.702949           0.730652
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.531276           0.483991         0.517006        0.022641
# 1            0.732400           0.667243         0.713598        0.030132
# 2            0.807176           0.735269         0.787026        0.032526
# 3            0.833413           0.762916         0.814300        0.032072
# 4            0.529344           0.484037         0.517447        0.023890
# ..                ...                ...              ...             ...
# 91           0.695540           0.719084         0.722349        0.023957
# 92           0.684090           0.714618         0.719066        0.026528
# 93           0.694591           0.718842         0.722328        0.024205
# 94           0.695452           0.719063         0.722351        0.023980
# 95           0.695540           0.719084         0.722349        0.023957
#
#     rank_test_score
# 0                84
# 1                45
# 2                22
# 3                 8
# 4                83
# ..              ...
# 91               29
# 92               37
# 93               33
# 94               25
# 95               29
#
# [96 rows x 17 columns]

# %%
print("The r2_score value for the best parameters {}".format(grid.best_params_))
# Out:
# The r2_score value for the best parameters {'booster': 'gbtree', 'learning_rate': 0.1, 'min_child_weight': 4, 'n_estimators': 50}

# %%
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8795626510616125

# %%
age=int(input('age='))
bmi=float(input('bmi='))
children=int(input('children='))
sex_male=int(input('sex male 0 or 1='))
smoker_yes=int(input('smoker yes 0 0r 1='))
future_prediction=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("The future prediction is {}".format(future_prediction))
# Out:
# age= 44
# bmi= 58
# children= 2
# sex male 0 or 1= 1
# smoker yes 0 0r 1= 1
# The future prediction is [49900.1]
