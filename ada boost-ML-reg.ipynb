# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype='int')
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
param_grid={'loss':['linear','square','exponential'],'n_estimators':[50,100,150],'learning_rate':[0.01,0.1,1]}
grid=GridSearchCV(AdaBoostRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 100, 150]},
#              verbose=3)

# %%
result=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        2.298496      0.568105         0.069649        0.057330
# 1        3.953234      0.521556         0.263051        0.047386
# 2        5.287682      0.705993         0.439875        0.156820
# 3        1.621652      0.185079         0.118423        0.058909
# 4        4.098839      0.194761         0.303033        0.137030
# 5        6.228270      0.858304         0.535509        0.115212
# 6        2.498562      0.472828         0.141062        0.066984
# 7        3.459187      0.800517         0.384521        0.123596
# 8        6.423010      0.346151         0.465318        0.166109
# 9        2.337653      0.350478         0.168749        0.102333
# 10       2.696585      0.457407         0.184864        0.106464
# 11       2.330621      0.230360         0.107119        0.048206
# 12       2.207874      0.416264         0.263203        0.163356
# 13       3.998330      0.592477         0.262967        0.151122
# 14       6.726700      0.527314         0.466264        0.223335
# 15       2.175678      0.298397         0.107091        0.075496
# 16       4.330581      0.616266         0.302085        0.191655
# 17       6.050356      0.470155         0.318417        0.135744
# 18       0.476189      0.194910         0.042223        0.039662
# 19       0.343308      0.050309         0.041160        0.046677
# 20       0.382472      0.209553         0.025486        0.021344
# 21       2.664807      0.229278         0.135708        0.062896
# 22       3.840522      0.232986         0.248310        0.129986
# 23       4.854143      0.316895         0.270188        0.088915
# 24       2.266906      0.318341         0.060580        0.063801
# 25       1.564298      0.466520         0.037753        0.010626
# 26       1.150969      0.176927         0.041939        0.005427
#
#    param_learning_rate   param_loss param_n_estimators  \
# 0                 0.01       linear                 50
# 1                 0.01       linear                100
# 2                 0.01       linear                150
# 3                 0.01       square                 50
# 4                 0.01       square                100
# 5                 0.01       square                150
# 6                 0.01  exponential                 50
# 7                 0.01  exponential                100
# 8                 0.01  exponential                150
# 9                  0.1       linear                 50
# 10                 0.1       linear                100
# 11                 0.1       linear                150
# 12                 0.1       square                 50
# 13                 0.1       square                100
# 14                 0.1       square                150
# 15                 0.1  exponential                 50
# 16                 0.1  exponential                100
# 17                 0.1  exponential                150
# 18                   1       linear                 50
# 19                   1       linear                100
# 20                   1       linear                150
# 21                   1       square                 50
# 22                   1       square                100
# 23                   1       square                150
# 24                   1  exponential                 50
# 25                   1  exponential                100
# 26                   1  exponential                150
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.870593
# 1   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.863505
# 2   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.859565
# 3   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.870766
# 4   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.862211
# 5   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.854249
# 6   {'learning_rate': 0.01, 'loss': 'exponential',...           0.873786
# 7   {'learning_rate': 0.01, 'loss': 'exponential',...           0.868548
# 8   {'learning_rate': 0.01, 'loss': 'exponential',...           0.863723
# 9   {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.830447
# 10  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.832399
# 11  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.824481
# 12  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.772844
# 13  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.671711
# 14  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.571890
# 15  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.829650
# 16  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.783666
# 17  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.742036
# 18  {'learning_rate': 1, 'loss': 'linear', 'n_esti...           0.827102
# 19  {'learning_rate': 1, 'loss': 'linear', 'n_esti...           0.813478
# 20  {'learning_rate': 1, 'loss': 'linear', 'n_esti...           0.805847
# 21  {'learning_rate': 1, 'loss': 'square', 'n_esti...           0.320370
# 22  {'learning_rate': 1, 'loss': 'square', 'n_esti...           0.312983
# 23  {'learning_rate': 1, 'loss': 'square', 'n_esti...           0.283275
# 24  {'learning_rate': 1, 'loss': 'exponential', 'n...           0.501627
# 25  {'learning_rate': 1, 'loss': 'exponential', 'n...           0.400478
# 26  {'learning_rate': 1, 'loss': 'exponential', 'n...           0.359986
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.817254           0.825322           0.843671
# 1            0.815483           0.822350           0.842039
# 2            0.810226           0.823726           0.840395
# 3            0.815779           0.826820           0.843067
# 4            0.810573           0.824290           0.840122
# 5            0.801707           0.822088           0.837980
# 6            0.816459           0.826031           0.841813
# 7            0.816841           0.824300           0.846149
# 8            0.815606           0.822640           0.842172
# 9            0.780313           0.811250           0.827311
# 10           0.781513           0.808005           0.830363
# 11           0.774509           0.804516           0.820453
# 12           0.722792           0.783311           0.780579
# 13           0.627924           0.686747           0.690972
# 14           0.537490           0.647905           0.606081
# 15           0.790171           0.809940           0.826475
# 16           0.743196           0.783806           0.796343
# 17           0.693900           0.755701           0.748889
# 18           0.786721           0.791056           0.823218
# 19           0.790570           0.807091           0.823188
# 20           0.710749           0.807757           0.805322
# 21           0.413660           0.515571           0.421830
# 22           0.372203           0.519433           0.359598
# 23           0.353022           0.482980           0.352917
# 24           0.514667           0.577289           0.530411
# 25           0.450778           0.523523           0.438323
# 26           0.424330           0.503795           0.387857
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.801317         0.831631        0.023784                3
# 1            0.801653         0.829006        0.021612                6
# 2            0.802908         0.827364        0.020551                8
# 3            0.801620         0.831610        0.023822                4
# 4            0.802971         0.828033        0.021266                7
# 5            0.801631         0.823531        0.020544                9
# 6            0.801276         0.831873        0.024752                1
# 7            0.802531         0.831674        0.023207                2
# 8            0.803603         0.829549        0.021178                5
# 9            0.800175         0.809899        0.018423               12
# 10           0.799955         0.810447        0.019140               11
# 11           0.799240         0.804640        0.017781               14
# 12           0.782846         0.768474        0.023148               18
# 13           0.734289         0.682329        0.034254               20
# 14           0.701432         0.612959        0.057408               21
# 15           0.799953         0.811238        0.015126               10
# 16           0.783640         0.778130        0.018140               17
# 17           0.758854         0.739876        0.023708               19
# 18           0.764290         0.798477        0.023637               15
# 19           0.811349         0.809135        0.010678               13
# 20           0.802618         0.786459        0.037891               16
# 21           0.589043         0.452095        0.092227               25
# 22           0.565191         0.425882        0.098163               26
# 23           0.546574         0.403754        0.096278               27
# 24           0.658763         0.556551        0.057152               22
# 25           0.629419         0.488504        0.080961               23
# 26           0.606292         0.456452        0.089147               24

# %%
print("The r2_score value for the best parameters {}".format(grid.best_params_))
# Out:
# The r2_score value for the best parameters {'learning_rate': 0.01, 'loss': 'exponential', 'n_estimators': 50}

# %%
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8801661386817821

# %%
age=int(input('age='))
bmi=float(input('bmi='))
children=int(input('children='))
sex_male=int(input('sex male 0 or 1='))
smoker_yes=int(input('smoker yes 0 0r 1='))
future_prediction=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("The future prediction is {}".format(future_prediction))
# Out:
# age= 50
# bmi= 55
# children= 3
# sex male 0 or 1= 0
# smoker yes 0 0r 1= 1
# The future prediction is [45459.74264891]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
