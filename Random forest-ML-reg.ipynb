# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype='int')
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['auto','log2','sqrt'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 23 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 17 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.79369848 0.81195502 0.79162733 0.81147647
#         nan        nan 0.79180748 0.81008541 0.79024882 0.81086485
#         nan        nan 0.80130077 0.80731263 0.78925875 0.81346052
#         nan        nan 0.78701296 0.81193317 0.79244492 0.8114309 ]
#   warnings.warn(
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'log2', 'sqrt'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
result=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005174      0.003083         0.000000        0.000000
# 1        0.002977      0.002804         0.000000        0.000000
# 2        0.064031      0.009913         0.003158        0.003253
# 3        0.370743      0.012516         0.018071        0.002878
# 4        0.048078      0.004786         0.006514        0.002640
# 5        0.384044      0.017395         0.018710        0.005708
# 6        0.002105      0.002583         0.000000        0.000000
# 7        0.000203      0.000405         0.000000        0.000000
# 8        0.115713      0.009437         0.002039        0.002964
# 9        1.030462      0.045825         0.020001        0.003584
# 10       0.116922      0.016462         0.005806        0.004684
# 11       1.072012      0.096129         0.018200        0.002978
# 12       0.001286      0.001580         0.000000        0.000000
# 13       0.002864      0.003231         0.000000        0.000000
# 14       0.040436      0.002133         0.008707        0.001205
# 15       0.390696      0.017698         0.019751        0.003067
# 16       0.051324      0.005849         0.006298        0.003544
# 17       0.351472      0.036186         0.014674        0.007868
# 18       0.004151      0.003028         0.000000        0.000000
# 19       0.002350      0.001970         0.000000        0.000000
# 20       0.047804      0.007304         0.010496        0.000733
# 21       0.385780      0.060862         0.012934        0.006495
# 22       0.046722      0.003767         0.009023        0.001258
# 23       0.375980      0.013727         0.013584        0.005572
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               auto                 10
# 1    squared_error               auto                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4    squared_error               sqrt                 10
# 5    squared_error               sqrt                100
# 6   absolute_error               auto                 10
# 7   absolute_error               auto                100
# 8   absolute_error               log2                 10
# 9   absolute_error               log2                100
# 10  absolute_error               sqrt                 10
# 11  absolute_error               sqrt                100
# 12    friedman_mse               auto                 10
# 13    friedman_mse               auto                100
# 14    friedman_mse               log2                 10
# 15    friedman_mse               log2                100
# 16    friedman_mse               sqrt                 10
# 17    friedman_mse               sqrt                100
# 18         poisson               auto                 10
# 19         poisson               auto                100
# 20         poisson               log2                 10
# 21         poisson               log2                100
# 22         poisson               sqrt                 10
# 23         poisson               sqrt                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.839090
# 3   {'criterion': 'squared_error', 'max_features':...           0.866940
# 4   {'criterion': 'squared_error', 'max_features':...           0.860077
# 5   {'criterion': 'squared_error', 'max_features':...           0.864774
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.845711
# 9   {'criterion': 'absolute_error', 'max_features'...           0.854642
# 10  {'criterion': 'absolute_error', 'max_features'...           0.848648
# 11  {'criterion': 'absolute_error', 'max_features'...           0.863279
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.858843
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.860895
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.828172
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.864693
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.811466
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.864162
# 22  {'criterion': 'poisson', 'max_features': 'sqrt...           0.848966
# 23  {'criterion': 'poisson', 'max_features': 'sqrt...           0.859627
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.772532           0.799214           0.803311
# 3            0.789551           0.802410           0.832209
# 4            0.777515           0.798317           0.786168
# 5            0.787605           0.807905           0.829065
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.781817           0.786199           0.787499
# 9            0.787335           0.812781           0.824587
# 10           0.754370           0.794595           0.802443
# 11           0.785055           0.811984           0.824863
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.771534           0.800504           0.823126
# 15           0.787967           0.800923           0.820225
# 16           0.772511           0.783068           0.813769
# 17           0.791183           0.810813           0.830504
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.784119           0.802889           0.787352
# 21           0.791139           0.805391           0.828386
# 22           0.771149           0.790754           0.797108
# 23           0.788702           0.814141           0.827278
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.754345         0.793698        0.028913               10
# 3            0.768665         0.811955        0.034353                2
# 4            0.736059         0.791627        0.040117               13
# 5            0.768034         0.811476        0.033526                4
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.757811         0.791807        0.029021               12
# 9            0.771082         0.810085        0.029126                7
# 10           0.751188         0.790249        0.035752               14
# 11           0.769142         0.810865        0.032715                6
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.752496         0.801301        0.037566                9
# 15           0.766552         0.807313        0.031982                8
# 16           0.748774         0.789259        0.028541               15
# 17           0.770109         0.813461        0.032551                1
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.749238         0.787013        0.021380               16
# 21           0.770588         0.811933        0.032197                3
# 22           0.754248         0.792445        0.032037               11
# 23           0.767406         0.811431        0.031737                5

# %%
print("The r2_score value for the best parameters {}".format(grid.best_params_))
# Out:
# The r2_score value for the best parameters {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.8696707750735517

# %%
age=int(input('age='))
bmi=float(input('bmi='))
children=int(input('children='))
sex_male=int(input('sex male 0 or 1='))
smoker_yes=int(input('smoker yes 0 0r 1='))
future_prediction=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("The future prediction is {}".format(future_prediction))
# Out:
# age= 33
# bmi= 49
# children= 2
# sex male 0 or 1= 0
# smoker yes 0 0r 1= 1
# The future prediction is [43544.209381]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
