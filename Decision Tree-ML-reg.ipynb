# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype='int')
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_features':['log2','sqrt','auto']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 22 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.58249548 0.60093144 0.64434797 0.57396429        nan        nan
#  0.61306616 0.62273038 0.60183494 0.61333224        nan        nan
#  0.57650171 0.62218461 0.57226346 0.62573293        nan        nan
#  0.6475064  0.59470677 0.63069739 0.57310077        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['log2', 'sqrt', 'auto'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(result)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.003764      0.004924         0.005544        0.006146
# 1        0.007481      0.010011         0.007055        0.001380
# 2        0.007299      0.002223         0.004915        0.004013
# 3        0.006445      0.005346         0.001031        0.002062
# 4        0.000000      0.000000         0.000000        0.000000
# 5        0.018398      0.036796         0.000000        0.000000
# 6        0.045209      0.047787         0.020928        0.041855
# 7        0.027127      0.019746         0.004174        0.005113
# 8        0.014963      0.012617         0.002610        0.002548
# 9        0.018243      0.019420         0.001725        0.002132
# 10       0.007159      0.009666         0.000000        0.000000
# 11       0.006288      0.012575         0.000000        0.000000
# 12       0.103566      0.034859         0.006000        0.005745
# 13       0.089944      0.060882         0.029554        0.048865
# 14       0.127218      0.051159         0.005255        0.004698
# 15       0.056370      0.023693         0.018169        0.023730
# 16       0.008230      0.007607         0.000000        0.000000
# 17       0.002136      0.004272         0.000000        0.000000
# 18       0.013226      0.005710         0.008652        0.012540
# 19       0.010954      0.005326         0.007012        0.004546
# 20       0.014011      0.006501         0.013858        0.011918
# 21       0.012331      0.007554         0.005765        0.003495
# 22       0.003919      0.002297         0.000000        0.000000
# 23       0.011613      0.013207         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               log2           best
# 1    squared_error               log2         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               auto           best
# 5    squared_error               auto         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               auto           best
# 11    friedman_mse               auto         random
# 12  absolute_error               log2           best
# 13  absolute_error               log2         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               auto           best
# 17  absolute_error               auto         random
# 18         poisson               log2           best
# 19         poisson               log2         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               auto           best
# 23         poisson               auto         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.441793
# 1   {'criterion': 'squared_error', 'max_features':...           0.645734
# 2   {'criterion': 'squared_error', 'max_features':...           0.688780
# 3   {'criterion': 'squared_error', 'max_features':...           0.679392
# 4   {'criterion': 'squared_error', 'max_features':...                NaN
# 5   {'criterion': 'squared_error', 'max_features':...                NaN
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.616188
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.695446
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.707796
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.656099
# 10  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 11  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 12  {'criterion': 'absolute_error', 'max_features'...           0.709433
# 13  {'criterion': 'absolute_error', 'max_features'...           0.645635
# 14  {'criterion': 'absolute_error', 'max_features'...           0.600091
# 15  {'criterion': 'absolute_error', 'max_features'...           0.449511
# 16  {'criterion': 'absolute_error', 'max_features'...                NaN
# 17  {'criterion': 'absolute_error', 'max_features'...                NaN
# 18  {'criterion': 'poisson', 'max_features': 'log2...           0.726443
# 19  {'criterion': 'poisson', 'max_features': 'log2...           0.745737
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.700526
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.695946
# 22  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 23  {'criterion': 'poisson', 'max_features': 'auto...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.666295           0.546514           0.629443
# 1            0.671361           0.645127           0.535063
# 2            0.447639           0.701926           0.721256
# 3            0.444506           0.414645           0.679064
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.556369           0.569691           0.656916
# 7            0.654134           0.549624           0.577430
# 8            0.701985           0.478100           0.489983
# 9            0.615137           0.704636           0.470648
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.501541           0.590454           0.422260
# 13           0.584600           0.613995           0.643708
# 14           0.456958           0.621318           0.622231
# 15           0.650949           0.680875           0.721835
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.660904           0.685237           0.543610
# 19           0.574599           0.533849           0.566959
# 20           0.668481           0.642865           0.570781
# 21           0.499336           0.624284           0.456339
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.628432         0.582495        0.080534               12
# 1            0.507372         0.600931        0.066352               10
# 2            0.662139         0.644348        0.100215                2
# 3            0.652215         0.573964        0.118681               14
# 4                 NaN              NaN             NaN               17
# 5                 NaN              NaN             NaN               17
# 6            0.666166         0.613066        0.044380                8
# 7            0.637017         0.622730        0.052677                5
# 8            0.631310         0.601835        0.099948                9
# 9            0.620140         0.613332        0.078197                7
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 12           0.658821         0.576502        0.103973               13
# 13           0.622985         0.622185        0.022332                6
# 14           0.560718         0.572263        0.061816               16
# 15           0.625495         0.625733        0.093772                4
# 16                NaN              NaN             NaN               17
# 17                NaN              NaN             NaN               17
# 18           0.621337         0.647506        0.062150                1
# 19           0.552390         0.594707        0.076784               11
# 20           0.570835         0.630697        0.052202                3
# 21           0.589598         0.573101        0.086090               15
# 22                NaN              NaN             NaN               17
# 23                NaN              NaN             NaN               17

# %%
print("The r2_score value for the best parameters {}".format(grid.best_params_))
# Out:
# The r2_score value for the best parameters {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}

# %%
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)
r_score
# Out:
# 0.7361471257325707

# %%
age=int(input('age='))
bmi=float(input('bmi='))
children=int(input('children='))
sex_male=int(input('sex male 0 or 1='))
smoker_yes=int(input('smoker yes 0 0r 1='))
future_prediction=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("The future prediction is {}".format(future_prediction))
# Out:
# age= 34
# bmi= 49
# children= 2
# sex male 0 or 1= 0
# smoker yes 0 0r 1= 0
# The future prediction is [12485.8009]
